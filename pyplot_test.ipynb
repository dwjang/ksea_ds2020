# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(6, 4))
xs = [1,2,3,4]
ys = [2,4,3,6]
plt.plot(xs, ys, "b--")
plt.ylabel('y label')
plt.xlabel("x label")
plt.ylim(0,10)
plt.xlim(0,5)
plt.title("line chart")
# Out:
# Text(0.5, 1.0, 'line chart')

# %%
plt.figure(figsize=(6, 4))
xs = [1,2,3,4]

ys = [2,4,3,6]
plt.plot(xs, ys, "b--")
plt.ylabel('y label')
plt.xlabel("x label")
plt.ylim(0,10)
plt.xlim(0,5)
plt.title("line chart")

ys2 = [3,1,4,2]
plt.plot(xs, ys2, "r-")

# %%
plt.figure(figsize=(12,4))
plt.subplot(221)
plt.plot(xs,ys)
plt.subplot(222)
plt.plot(xs,ys, "r+")
plt.subplot(223)
plt.plot(xs, ys, "b--")
plt.subplot(224)
plt.plot(xs, ys, "r:")

# %%
import numpy as np
import random

random.seed(6728637)

mu = 0
sigma = 1
npoints = 1000
xs = []
for i in range(npoints):
    xs.append(random.gauss(mu, sigma))

plt.hist(xs, bins=np.linspace(-5,5,100))
plt.title("gaussin distribution")
plt.xlabel("x values")
plt.ylabel("number of x occurred")
plt.show()

# %%
xs = [0,1,2,3]
ys = [10, 8,15,7]
plt.bar(xs, ys, width=0.5)
plt.ylim(0,20)
plt.title("bar chart")
plt.xlabel("x values")
plt.ylabel("y values")
# Out:
# Text(0, 0.5, 'y values')

# %%
ys = [10, 8,15,7]
ynames = ["x", "y", "z", "w"]
plt.pie(ys, labels=ynames, explode=(0.2,0.1,0,0))
plt.title("bar chart")
# Out:
# Text(0.5, 1.0, 'bar chart')

# %%
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np


fig = plt.figure()
ax = fig.gca(projection='3d')

# Make data.
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

# Customize the z axis.
ax.set_zlim(-1.01, 1.01)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

# %%
w = 3
Y, X = np.mgrid[-w:w:100j, -w:w:100j]
U = -1 - X**2 + Y
V = 1 + X - Y**2

plt.streamplot(X, Y, U, V, density=[0.5, 1])
plt.title('Varying Density')
# Out:
# Text(0.5, 1.0, 'Varying Density')

# %%
import random

random.seed(2348923)
xs = []
ys = []

for i in range(1000):
    x = 3 * random.random()
    xs.append(x)
    ys.append(x**2 + (2*random.random() - 1))

plt.scatter(xs, ys, s=0.1, c="red")

# %%
plt.figure(figsize=(6, 4))
xs = [1,2,3,4]
ys = [1000,10,5,0.1]
plt.plot(xs, ys, "r*")
plt.ylabel('y label')
plt.xlabel("x label")
plt.title("line chart")
plt.yscale("log")
